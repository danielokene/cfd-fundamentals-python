# %%
# Importing dependencies
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
# Running a simple velocity flow (x represents space and u velocity)
x = np.linspace(0, 10, 100)
u = np.sin(x)

plt.plot(x,u)
plt.title("Simple Velocity Profile")
plt.xlabel("Distance")
plt.ylabel("Velocity")
plt.show()
